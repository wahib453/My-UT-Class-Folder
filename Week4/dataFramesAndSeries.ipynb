# %%
import pandas as pd

# %%
a_List_Of_Cities = ['Austin','New York','Tokyo','Qingdao']

# %%
city_Series = pd.Series(a_List_Of_Cities)

# %%
type(city_Series)
# Out:
# pandas.core.series.Series

# %%
city_Series.count
# Out:
# <bound method Series.count of 0      Austin
# 1    New York
# 2       Tokyo
# 3     Qingdao
# dtype: object>

# %%
for city in city_Series:
    print(city)
# Out:
# Austin
# New York
# Tokyo
# Qingdao

# %%
city_Series[0]
# Out:
# 'Austin'

# %%
city_Series.T
# Out:
# 0      Austin
# 1    New York
# 2       Tokyo
# 3     Qingdao
# dtype: object

# %%
clockWorkOrange = {
    "MovieTitle" : "Clockwork Orange", "Genre" : "Horror"
}
mandalorian = {
    "MovieTitle" : "The Mandalorian", "Genre" : "Sci Fi"
}
pulpFiction = {
    "MovieTitle" : "Pulp Fiction", "Genre" : "Action"
}

# %%
a_list_of_movies = [clockWorkOrange,mandalorian,pulpFiction]

# %%
movies_df = pd.DataFrame(a_list_of_movies)

# %%
type(movies_df)
# Out:
# pandas.core.frame.DataFrame

# %%
movies_df['MovieTitle']
# Out:
# 0    Clockwork Orange
# 1     The Mandalorian
# 2        Pulp Fiction
# Name: MovieTitle, dtype: object

# %%
type(movies_df['MovieTitle'])
# Out:
# pandas.core.series.Series

# %%
movies_df['MovieTitle'][0]
# Out:
# 'Clockwork Orange'

# %%
movies_df.T
# Out:
#                            0                1             2
# MovieTitle  Clockwork Orange  The Mandalorian  Pulp Fiction
# Genre                 Horror           Sci Fi        Action
