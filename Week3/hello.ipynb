# %%
print("Hello")
# Out:
# Hello

# %%
someString = "Hello"

# %%
print(someString)
# Out:
# Hello

# %%
# This is comment 
myOldDog: str = "Laika"

# %%
type(myOldDog)
# Out:
# str

# %%
myAge = 33

# %%
print(myAge + 1)
# Out:
# 34

# %%
type(33)
# Out:
# int

# %%
type(33.0)
# Out:
# float

# %%
type(int(33.0))
# Out:
# int

# %%
str(33.0)
# Out:
# '33.0'

# %%
# six types in python
# int float bool str None object

# %%
myName = "Shawn Hartley"
myAge = 32
myBDay = '12/17/1987'

# %%
# String interpolation

myIntroduction = f"""
My name is {myName} and I am {myAge} years old.
I was born {myBDay}
"""

# %%
print(myIntroduction)
# Out:
# My name is Shawn Hartley and I am 32 years old.
# I was born 12/17/1987
